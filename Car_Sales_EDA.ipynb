# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Exploratory Data Analysis(EDA) is the method used to analyze and summarize data sets.It is the way of exploring data through visual summaries and graphics and identifies general patterns in the data. These patterns include outliers and features of the data that might be unexpected. EDA is an important first step in any data analysis.

# %% [markdown]
# # Table of Contents
#
#
#    #### IMPORTING LIBRARIES
#
#    #### LOADING DATA
#
#    #### DATA PREPROCESSING
#
#    #### DATA ANALYSIS

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading Dataset

# %%
data=pd.read_excel('C:\DATASCIENCE\DATASET\EXCEL\Car_Sales.xlsx')

# %%
data
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %% [markdown]
# ### First Five Rows of the Data

# %%
data.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# ### Last Five Rows of the Data

# %%
data.tail()
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# 9571  2011     Tucson  front
# 9572  1986  Passat B2  front
# 9573  2008     ML 350   full
# 9574  2008     ES 350  front
# 9575  2007         Q7   full

# %% [markdown]
# ### Columns Names of the Data

# %%
data.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %% [markdown]
# ### Data Types of each Column

# %%
data.dtypes
# Out:
# car              object
# price           float64
# body             object
# mileage           int64
# engV            float64
# engType          object
# registration     object
# year              int64
# model            object
# drive            object
# dtype: object

# %% [markdown]
# ### Shape of the Data

# %%
data.shape
# Out:
# (7710, 10)

# %% [markdown]
# ### Information of our Data like Column Names,Data types ,Memory usage etc

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %% [markdown]
# ### Summary Statistics of Numerical Columns of the Data

# %%
data.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %% [markdown]
# ### Statistical Mean of each Numerical Column

# %%
data.mean()
# Out:
# price      15633.317316
# mileage      138.862364
# engV           2.646344
# year        2006.605994
# dtype: float64

# %% [markdown]
# ### Median of Numerical Columns

# %%
data.median()
# Out:
# price      9200.0
# mileage     128.0
# engV          2.0
# year       2008.0
# dtype: float64

# %% [markdown]
# ### Standard Deviation of Numerical Columns

# %%
data.std()
# Out:
# price      24106.523436
# mileage       98.629754
# engV           5.927699
# year           7.067924
# dtype: float64

# %% [markdown]
# ### Sum of Null values of each Columns

# %%
data.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %% [markdown]
# ### Total Sum of Duplicated Values in the data

# %%
data.duplicated().sum()
# Out:
# 113

# %% [markdown]
# ### Removing Duplicates from the data

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %% [markdown]
# ### Number of unique values of the Columns

# %%
data.nunique()
# Out:
# car               87
# price           1353
# body               6
# mileage          442
# engV             117
# engType            4
# registration       2
# year              56
# model            863
# drive              3
# dtype: int64

# %% [markdown]
# ### Renaming Columns into New Names

# %%
data= data.rename(columns={"car": "Car_Name","price":"Price","body":"Body","mileage":"Mileage","engV":"EngV",
                        "engType":"Engine_Type","registration":"Registration","year":"Year","model":"Model","drive":"Drive" })
data.head(5)
# Out:
#         Car_Name    Price       Body  Mileage  EngV Engine_Type Registration  \
# 0           Ford  15500.0  crossover       68   2.5         Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8         Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5      Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8      Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN       Other          yes
#
#    Year    Model  Drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# ### Replacing NaN values of drive column with full,rear and front

# %%
idx = data['Drive'].index[data['Drive'].isnull()]
total_nan_len = len(idx)
first_nan = total_nan_len//3
# fill first 30% of full
data.loc[idx[0:first_nan], 'Drive'] = 'full'
# fill next 30% of rear
data.loc[idx[first_nan:6539], 'Drive'] = 'rear'
# fill last 40% of front
data.loc[idx[6540:total_nan_len],'Drive']='front'

# %%
data
# Out:
#            Car_Name    Price       Body  Mileage  EngV Engine_Type  \
# 0              Ford  15500.0  crossover       68   2.5         Gas
# 1     Mercedes-Benz  20500.0      sedan      173   1.8         Gas
# 2     Mercedes-Benz  35000.0      other      135   5.5      Petrol
# 3     Mercedes-Benz  17800.0        van      162   1.8      Diesel
# 4     Mercedes-Benz  33000.0      vagon       91   NaN       Other
# ...             ...      ...        ...      ...   ...         ...
# 9571        Hyundai  14500.0  crossover      140   2.0         Gas
# 9572     Volkswagen   2200.0      vagon      150   1.6      Petrol
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5      Petrol
# 9574          Lexus  16999.0      sedan      150   3.5         Gas
# 9575           Audi  22500.0      other       71   3.6      Petrol
#
#      Registration  Year      Model  Drive
# 0             yes  2010       Kuga   full
# 1             yes  2011    E-Class   rear
# ...

# %% [markdown]
# ### Count of unique values of EngV Column

# %%
data['EngV'].value_counts()
# Out:
# 2.00     1525
# 1.60     1224
# 1.50      689
# 3.00      672
# 1.80      575
#          ...
# 1.12        1
# 1.36        1
# 55.00       1
# 4.39        1
# 74.00       1
# Name: EngV, Length: 117, dtype: int64

# %% [markdown]
# ### Replacing Missing Values with mean of EngV Column

# %%
mean=data['EngV'].mean() 
data['EngV'].fillna(value=mean, inplace=True)

# %%
data
# Out:
#            Car_Name    Price       Body  Mileage      EngV Engine_Type  \
# 0              Ford  15500.0  crossover       68  2.500000         Gas
# 1     Mercedes-Benz  20500.0      sedan      173  1.800000         Gas
# 2     Mercedes-Benz  35000.0      other      135  5.500000      Petrol
# 3     Mercedes-Benz  17800.0        van      162  1.800000      Diesel
# 4     Mercedes-Benz  33000.0      vagon       91  2.641444       Other
# ...             ...      ...        ...      ...       ...         ...
# 9571        Hyundai  14500.0  crossover      140  2.000000         Gas
# 9572     Volkswagen   2200.0      vagon      150  1.600000      Petrol
# 9573  Mercedes-Benz  18500.0  crossover      180  3.500000      Petrol
# 9574          Lexus  16999.0      sedan      150  3.500000         Gas
# 9575           Audi  22500.0      other       71  3.600000      Petrol
#
#      Registration  Year      Model  Drive
# 0             yes  2010       Kuga   full
# ...

# %% [markdown]
# ### Now we have removed all the rows which contain the Null values

# %%
data.isnull().sum()
# Out:
# Car_Name        0
# Price           0
# Body            0
# Mileage         0
# EngV            0
# Engine_Type     0
# Registration    0
# Year            0
# Model           0
# Drive           0
# dtype: int64

# %%
#data.drop('index',axis=1)

# %% [markdown]
# ### Correlation between columns

# %%
data.corr()
# Out:
#             Price   Mileage      EngV      Year
# Price    1.000000 -0.312965  0.048277  0.375440
# Mileage -0.312965  1.000000  0.047239 -0.489326
# EngV     0.048277  0.047239  1.000000 -0.041933
# Year     0.375440 -0.489326 -0.041933  1.000000

# %% [markdown]
# ### Outlier Detection from Numerical columns And Remove it using IQR Method

# %%
sns.boxplot(x=data['Price'],palette='hls')
plt.show()

# %%
sns.boxplot(x=data['Mileage'],palette='hls')
plt.show()

# %%
sns.boxplot(x=data['EngV'],palette='hls')
plt.show()

# %%
sns.boxplot(x=data['Year'],palette='hls')
plt.show()

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Price      11501.000000
# Mileage      125.000000
# EngV           1.041444
# Year           8.000000
# dtype: float64

# %%
data= data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]
data.shape
# Out:
# (7710, 10)

# %%
sns.boxplot(x=data['Price'],palette='hls')
plt.show()

# %%
sns.boxplot(x=data['Mileage'],palette='hls')
plt.show()

# %%
sns.boxplot(x=data['EngV'],palette='hls')
plt.show()

# %%
sns.boxplot(x=data['Year'],palette='hls')
plt.show()

# %%
data['Model'].value_counts()
# Out:
# E-Class         161
# Vito ����.      158
# A6              156
# Kangoo ����.    141
# Camry           131
#                ...
# 10                1
# 350Z              1
# GC6               1
# Escort van        1
# Gran Move         1
# Name: Model, Length: 688, dtype: int64

# %% [markdown]
# ### Replacing values with new values

# %%
data= data.replace(['Vito ����.', 'Kangoo ����.', 'Transit ����.','H1 ����.','Sprinter 324 ����.','T5 (Transporter) ����.'],
                 ['Vito', 'Kangoo','Transit','H1','Sprinter','Transporter'])

# %%
data['Model'].value_counts()
# Out:
# E-Class       161
# Vito          158
# A6            156
# Kangoo        141
# Camry         131
#              ...
# 10              1
# 350Z            1
# GC6             1
# Escort van      1
# Gran Move       1
# Name: Model, Length: 688, dtype: int64

# %% [markdown]
# ### Selecting 3 Columns Randomly

# %%
df4=data[['Year','Model','Price']]
df4
# Out:
#       Year    Model    Price
# 0     2010     Kuga  15500.0
# 1     2011  E-Class  20500.0
# 3     2012    B 180  17800.0
# 4     2013  E-Class  33000.0
# 5     2013  X-Trail  16600.0
# ...    ...      ...      ...
# 9570  2007    Rav 4  14474.0
# 9571  2011   Tucson  14500.0
# 9573  2008   ML 350  18500.0
# 9574  2008   ES 350  16999.0
# 9575  2007       Q7  22500.0
#
# [7710 rows x 3 columns]

# %% [markdown]
# ### LinePlot of Year vs Price Columns

# %%
sns.lineplot(x='Year',y='Price',data=df4,color='red')
plt.show()

# %% [markdown]
# ### Filtering Data Based on certain columns

# %% [markdown]
# #### Filtering Data based on Car Name Ford,Price of Car less than 15000 and Drive Front

# %%
df=data.loc[(data['Car_Name']=='Ford') & (data['Price']< 15000)&(data['Drive']=='front')]
df
# Out:
#      Car_Name    Price   Body  Mileage  EngV Engine_Type Registration  Year  \
# 280      Ford  12500.0  sedan       63   1.6      Petrol          yes  2013
# 313      Ford  12099.0  sedan      109   1.6         Gas          yes  2011
# 317      Ford  12300.0  hatch       71   1.6         Gas          yes  2013
# 356      Ford   5900.0  hatch      138   1.4      Petrol          yes  2008
# 415      Ford   6450.0  hatch      150   1.4      Petrol          yes  2007
# ...       ...      ...    ...      ...   ...         ...          ...   ...
# 9307     Ford   3300.0  hatch      150   1.3       Other          yes  1998
# 9370     Ford  10800.0    van      200   2.2      Diesel          yes  2007
# 9402     Ford   9599.0  hatch       30   1.0      Petrol          yes  2014
# 9493     Ford   5500.0  sedan      215   2.0      Petrol          yes  2006
# 9494     Ford   7100.0  hatch       70   1.6      Petrol          yes  2006
#
#         Model  Drive
# 280     Focus  front
# ...

# %%
df.head()
# Out:
#     Car_Name    Price   Body  Mileage  EngV Engine_Type Registration  Year  \
# 280     Ford  12500.0  sedan       63   1.6      Petrol          yes  2013
# 313     Ford  12099.0  sedan      109   1.6         Gas          yes  2011
# 317     Ford  12300.0  hatch       71   1.6         Gas          yes  2013
# 356     Ford   5900.0  hatch      138   1.4      Petrol          yes  2008
# 415     Ford   6450.0  hatch      150   1.4      Petrol          yes  2007
#
#       Model  Drive
# 280   Focus  front
# 313   Focus  front
# 317  Fiesta  front
# 356  Fiesta  front
# 415  Fiesta  front

# %% [markdown]
# ### Statistical Functions

# %%
df.mean()
# Out:
# Price      7879.193039
# Mileage     134.350254
# EngV          1.669369
# Year       2008.065990
# dtype: float64

# %%
df.median()
# Out:
# Price      7999.0
# Mileage     130.0
# EngV          1.6
# Year       2009.0
# dtype: float64

# %%
df.std()
# Out:
# Price      3191.665561
# Mileage      74.844084
# EngV          0.396930
# Year          5.087070
# dtype: float64

# %%
df.corr()
# Out:
#             Price   Mileage      EngV      Year
# Price    1.000000 -0.570699 -0.081352  0.783074
# Mileage -0.570699  1.000000  0.423152 -0.645962
# EngV    -0.081352  0.423152  1.000000 -0.272240
# Year     0.783074 -0.645962 -0.272240  1.000000

# %%
data.loc[(data['Car_Name']=='Hyundai') & (data['Price']> 25000)|(data['Year']==2016)]
# Out:
#            Car_Name       Price       Body  Mileage  EngV Engine_Type  \
# 10           Nissan  20447.1540  crossover        0   1.2      Petrol
# 21           Nissan  26033.5530  crossover        0   1.6      Diesel
# 53    Mercedes-Benz      0.0000  crossover        0   3.0      Diesel
# 58              Kia  20633.8860  crossover        0   1.7      Diesel
# 105         Porsche      0.0000  crossover        0   3.0      Diesel
# ...             ...         ...        ...      ...   ...         ...
# 9214         Subaru  32300.0000  crossover        0   2.0      Petrol
# 9234        Hyundai  12800.7750      hatch        0   1.4      Petrol
# 9382         Suzuki  15486.9000      hatch        0   1.2      Petrol
# 9483           Opel  20120.0000      sedan        0   1.6      Diesel
# 9484         Nissan  29077.9515  crossover        0   1.6      Diesel
#
#      Registration  Year      Model  Drive
# 10            yes  2016    Qashqai  front
# ...

# %%
display(data[(data['Car_Name']=='Lexus') & (data['Engine_Type']=='Petrol') &(data['Mileage']<90)&data['Body'].str.startswith('s')]
        [['Car_Name','Engine_Type','Body']])
# Out:
#      Car_Name Engine_Type   Body
# 221     Lexus      Petrol  sedan
# 910     Lexus      Petrol  sedan
# 2385    Lexus      Petrol  sedan
# 6260    Lexus      Petrol  sedan
# 6690    Lexus      Petrol  sedan

# %%
data2=data[(data['Price'] <=15000) | (data['Model'] == "Sonata")]
data2
# Out:
#            Car_Name    Price       Body  Mileage      EngV Engine_Type  \
# 6             Honda   6500.0      sedan      199  2.000000      Petrol
# 7           Renault  10500.0      vagon      185  1.500000      Diesel
# 13              BMW   4700.0      sedan      200  2.641444      Petrol
# 30           Nissan  13980.0      hatch       31  2.641444       Other
# 32       Volkswagen  10700.0      sedan      147  2.000000      Petrol
# ...             ...      ...        ...      ...       ...         ...
# 9565  Mercedes-Benz   8900.0      hatch      155  1.500000      Petrol
# 9567           Jeep  13990.0  crossover      210  3.000000      Diesel
# 9568  Mercedes-Benz   5000.0      vagon      248  2.000000         Gas
# 9570         Toyota  14474.0  crossover      115  2.000000      Petrol
# 9571        Hyundai  14500.0  crossover      140  2.000000         Gas
#
#      Registration  Year           Model  Drive
# 6             yes  2003          Accord  front
# ...

# %%
list_values = ["Volkswagen", "Mercedes-Benz",'front']
   
# not in filter with multiple column
df2 = data[~data[['Car_Name', 'Drive']].isin(list_values).any(axis=1)]
print(df2)
# Out:
#         Car_Name      Price       Body  Mileage      EngV Engine_Type  \
# 0           Ford  15500.000  crossover       68  2.500000         Gas
# 5         Nissan  16600.000  crossover       83  2.000000      Petrol
# 13           BMW   4700.000      sedan      200  2.641444      Petrol
# 21        Nissan  26033.553  crossover        0  1.600000      Diesel
# 25           BMW  23900.000  crossover      235  3.000000      Diesel
# ...          ...        ...        ...      ...       ...         ...
# 9547  Mitsubishi  12900.000      sedan       40  2.000000      Petrol
# 9561     Hyundai   5200.000      other      250  2.500000      Diesel
# 9567        Jeep  13990.000  crossover      210  3.000000      Diesel
# 9570      Toyota  14474.000  crossover      115  2.000000      Petrol
# 9575        Audi  22500.000      other       71  3.600000      Petrol
#
#      Registration  Year             Model Drive
# 0             yes  2010              Kuga  full
# ...

# %% [markdown]
# ### Dist Plot of Price column

# %%
plt.figure(figsize=(6,3.2),dpi=150)
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=8)

sns.distplot(data['Price'],color='crimson')
plt.grid()
plt.show()

# %% [markdown]
# ### Count Plot of Engine Type Column with hue drive

# %%
plt.figure(figsize=(10,6))
sns.countplot('Engine_Type',hue='Drive',data=data,palette='cividis_r')
plt.show()

# %% [markdown]
# ### Countplot of Registration column

# %%
sns.countplot('Registration',data=data)
plt.show()

# %% [markdown]
# ### Countplot of drive column

# %%
plt.figure(figsize=(8,4))
sns.countplot(y='Drive',data=data,palette='YlGnBu_r')
plt.xlabel('Count',color='blue')
plt.grid()
plt.show()

# %% [markdown]
# ### Histplot of Year Column

# %%
plt.figure(figsize=(9,6))
sns.histplot(data['Year'],palette='Spectral',kde=True,binwidth=2)
plt.grid(axis='y',color='green',linestyle='--',linewidth=0.5)
plt.show()

# %% [markdown]
# ### PieChart of Body Column

# %%
plt.figure(figsize=(8,6))
explode=[0,0.1,0,0.1,0,0.1]
plt.pie(data['Body'].value_counts(),labels=['Sedan','Crossover','Hatch','Van','Other','Vagon'],
        explode=explode,autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### Extracting Data After the year 1990

# %%
data1 = data[data['Year']>1999]

# %% [markdown]
# ### Countplot of Body,Drive,Engine_Type,Registration Columns

# %%
fig=plt.subplots(figsize=(12,16))

for i,col in enumerate(['Body','Drive','Engine_Type','Registration']):
    plt.subplot(4,2, i+1)
    sns.countplot(data1[col],palette='YlOrBr')
    plt.tight_layout()

# %% [markdown]
# ### Barplot of Year vs Price columns

# %%
plt.figure(figsize=(10,4))
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=6)

sns.barplot(x='Year',y='Price',data=data1,color='firebrick')
plt.title("Year VS Price",color='red')
plt.xticks(rotation=45)
plt.grid()
#plt.legend()
plt.show()

# %% [markdown]
# ### Scatter Plot of Engine Type vs Price

# %%
x=data1['Engine_Type']
y=data1['Price']
plt.scatter(x, y,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# ### ViolinPlot of Engine_Type vs Price

# %%
sns.violinplot(x ="Engine_Type", y ="Price", data =data1)
# Out:
# <AxesSubplot:xlabel='Engine_Type', ylabel='Price'>

# %% [markdown]
# ### Box plot of Engine Type VS Mileage

# %%
sns.boxplot(x='Engine_Type', y='Mileage', data=data1,palette='mako')
plt.show()

# %% [markdown]
# ### Barplot of Features with Price Column

# %%
fig=plt.subplots(figsize=(14, 14))

for i, feature in enumerate(['Engine_Type','Drive','Year']):
    plt.subplot(4,2, i+1)
    sns.barplot(data1[feature], data1['Price'])
    plt.tight_layout()
    plt.grid()

# %% [markdown]
# ### Pairplot of the data

# %%
sns.pairplot(data1,height=2.5)
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.subplots(figsize=(10,5))
sns.heatmap(data1.corr(),annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# #### These are some of the  important steps in Exploratory data analysis and these are some general procedure that must follow in order to perform EDA
